-- %% [markdown]
-- #### Step 1:
-- load the data from landing zone and move it to bronze layer

-- %%
create streaming table orders_bronze1
comment "load from file to delta table"
as 
select *,_metadate.file_name as input_file_name,
current_timestamp() as ingestion_time
from
