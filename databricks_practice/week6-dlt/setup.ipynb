# %%
my_catalog="dlt"
my_schema="dlt_practice"
my_volume="dlt_data"
spark.sql(f"create schema if not exists {my_catalog}.{my_schema}")
spark.sql(f"create volume if not exists {my_catalog}.{my_schema}.{my_volume}")
volumn_path=f"/volumes/{my_catalog}/{my_schema}/{my_volume}/"
download_url="https://health.data.ny.gov/api/views"
filename="names.csv"
dbutils.fs.cp(download_url,volumn_path+filename)

# %%
dbutils.fs.ls("/volumes/")
