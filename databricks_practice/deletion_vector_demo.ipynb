# %%
# %sql
create volume if not exists deletion_vector_demo1;

# %%
data=[(1,"prasanna"),(2,"dharshini"),(3,"sai")]
df=spark.createDataFrame(data,["id","name"])
display(df)

# %%
volume_path="/Volumes/workspace/default/deletion_vector_demo1/dv_demo/"
df.write.format("delta").mode("overwrite").save("/Volumes/workspace/default/deletion_vector_demo1/dv_demo/")

# %%
# %sql
select * from delta.`/Volumes/workspace/default/deletion_vector_demo1/dv_demo`;

# %%
data=[(4,"gva"),(5,"siva")]
new_df=spark.createDataFrame(data,["id","name"])
new_df.write.format("delta").mode("append").save("/Volumes/workspace/default/deletion_vector_demo1/dv_demo")

# %%
# %sql
select * from json.`/Volumes/workspace/default/deletion_vector_demo1/dv_demo/_delta_log/00000000000000000001.json`

# %%
# %sql
delete from delta.`/Volumes/workspace/default/deletion_vector_demo1/dv_demo/` where id=4;

# %%
# %sql
describe history delta.`/Volumes/workspace/default/deletion_vector_demo1/dv_demo/`

# %%
# %sql
describe history delta.`/Volumes/workspace/default/deletion_vector_demo1/dv_demo/`

# %%
# %sql

select * from json.`/Volumes/workspace/default/deletion_vector_demo1/dv_demo/_delta_log/00000000000000000003.json`

# %%
# %sql
describe history delta.`/Volumes/workspace/default/deletion_vector_demo1/dv_demo/`

# %%
# %sql
restore table delta.`/Volumes/workspace/default/deletion_vector_demo1/dv_demo/` to version as of 2

# %%
# %sql
describe history delta.`/Volumes/workspace/default/deletion_vector_demo1/dv_demo/`
