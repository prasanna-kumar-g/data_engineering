# %% [markdown]
# ### find metastore

# %%
# %sql
select current_metastore();

# %%
# %sql
select current_catalog();

# %%
# %sql
show schemas;

# %%
# %sql
create table if not exists default.student(id int , name string);

# %%
# %sql
describe formatted  student;

# %%
# %sql
insert into default.student values(1,'prasanna');

# %%
# %sql
desc extended default.student;

# %%
# %sql
select current_catalog();

# %%
# %fs ls /volumes
