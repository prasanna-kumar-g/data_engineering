# %%
5+3

# %%
spark

# %%
display(dbutils.fs.ls('/databricks-datasets/airlines'))

# %%
df=spark.read.option("header",True).csv("/databricks-datasets/airlines/part-00000")

# %%
display(df)

# %%
df_filtered=df.filter("cancelled==1")

# %%
df_filtered.count()

# %%
df_grp=df_filtered.groupBy("dest").count()
display(df_grp)

# %%
df_grp.createOrReplaceTempView("cancelled_flights")

# %%
# %sql
select * from cancelled_flights

# %%
# %sh
pwd
